# %% [markdown]
# # Natural Language Processing
#
# ---
#
# ## Import the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ---
#
# ## Import the dataset

# %%
dataset = pd.read_csv('0700-Data/Restaurant_Reviews.tsv', delimiter='\t', quoting=3)

# %% [markdown]
# ---
#
# ## Clean the data

# %%
import re
import nltk

nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

corpus = []

for i in range(0, len(dataset)):
    review = re.sub('[^a-zA-Z]', ' ', dataset['Review'][i])
    review.lower()
    review.split()
    ps = PorterStemmer()
    all_stopwords = stopwords.words('english')
    all_stopwords.remove('not')
    review = [ps.stem(word) for word in review if not word in set(all_stopwords)]
    review = ''.join(review)
    corpus.append(review)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rgonzalez\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(corpus)
# Out:
# ['ww    lve h plce ', 'cru  n g ', 'n  n he exure w ju n ', 'sppe b urng he le m bnk hl ff rck seve recenn n lve  ', 'the elecn n he enu w gre n  were he prce ', 'nw i  geng ngr n i wn  n ph ', 'hnel  n  e that freh  ', 'the pe were lke rubber n u cul ell he h been e up he f e beng kep uner  wrer ', 'the fre were gre  ', 'a gre uch ', 'servce w ver prp ', 'wul n g bck ', 'the cher h n cre wh  ever n wh i h    ll ene up beng w verprce ', 'i re he cpe c rvl  chcken  wh crnberr    ', 'i w gue becue i w pre ure h w hun hr ', 'i w hcke becue n gn nce ch nl ', 'hghl recene ', 'wre w  lle lw n ervce ', 'th plce  n wrh ur e  le lne veg ', ' n lke  ll ', 'the burr blh ', 'the f  zng ', 'servce  l cue ', 'i cul cre le    the nerr  ju beuful ', 's he perfre ', 'th  rgh    he re velve cke     hhh h uff   g ', '  the never brugh  l we ke fr ', 'th hle n he wll h gre mexcn ree c  n frenl ff ', 'tk n hur  ge ur f nl   ble n reurn  f w luke wr  our ever w runnng run lke he w ll verwhele ', 'the wr w he ln h ', 'al here re cb lke  burger  fre  n beer fr    whch   ecen el ', 'th w lke he fnl blw ', 'i fun h plce b ccen n i cul n be hpper ', 'ee lke  g quck plce  grb  be f e flr pub f  bu  urelf  fvr n lk elewhere ', 'overll  i lke h plce  l ', 'the nl reeeng qul f he reurn w h  w ver nexpenve ', 'aple prn n g prce ', 'pr ervce  he wer e e feel lke i w up ever e he ce  he ble ', 'm fr v  hr w  elgh ', 'servce uck ', 'the hrp ener n  ', 'there  n  el g enugh h wul rg e n h eblhen gn ', 'hr  juge wheher hee e were g becue we were gre u b he ele rf n n  wn  e  fr fer f geng ck ', 'on  pve ne  ur erver w ver enve n prve gre ervce ', 'frzen puck f gu  wh e f he wr peple behn he reger ', 'the nl hng i  lke w he pre rb n eer ecn ', 'i   b he f   n generc ', 'the burger  g beef  cke ju rgh ', 'if u wn  nwch ju g  n frehue     ', 'm e greek l wh he greek reng w    n he p n huu w ver refrehng ', 'we rere he uck rre n  w pnk n ener n he ne wh  nce chr n he ue ', 'he ce runnng fer u when he relze  hubn h lef h ungle n he ble ', 'ther chw en   g ', 'the hve hrrble ue wr cuer  n lk wn  ech ne when cuer n  enj her f ', 'the prn w huge ', 'lve    frenl erver  gre f  wnerful n gnve enu ', 'the her ack grll n wnwn veg  n bluel fl lne excue fr  reurn ', 'n uch ef n lke   rng f p  he b ', 'the l h ju he rgh un f uce  n ver pwer he cllp  whch w perfecl cke ', 'the rppe bnn w n nl rppe  bu perfe n ele ', 'a le hnk  refll  wer befre i ruggle  wve u ver fr    nue ', 'th plce receve r fr her appetizers   ', 'the cckl re ll hne n elcu ', 'we  efnel g bck here gn ', 'we re  gl we fun h plce ', 'gre f n ervce  huge prn n he gve  lr cun ', 'alw  gre e  d grng ', 'upe     wen bck fr  ecn e n  w ll ju  zng', 'we g he f n pprenl he hve never her f l n he ber n he fh w chew ', 'a gre w  fnh  gre ', 'the el nclue   ng n   rnk  n jeff wen bve n ben wh we expece ', '  rell  rell g rce  ll he e ', 'the ervce w eh ', 'i k ver    n  ge her lkhke  whch w nhng re hn chcle lk ', 'i gue i hul hve knwn h h plce wul uck  becue   ne f he exclbur  bu i n  ue  cn ene ', 'the cllp h  que ppllng fr vlue  well ', '  e   ver b cuer servce  ', 'the wee p fre were ver g n ene well ', 't  he ecn e i ve been  her lunch buffe n  w pre g ', 'there   uch g f n veg h i feel chee fr wng n eng pprun b gng  rce n cpn ', 'cng here  lke experencng n unerwhelng relnhp where bh pre cn  w fr he her pern  k  brek up ', 'wlke n n he plce elle lke n l gree rp n nl   her here eng ', 'the urke n r beef were bln ', 'th plce h  ', 'the pn cke everne re rvng bu e lke  ugr er lre  he ple f  x er l ', 'i lve he ph n he prng rll h  u u hve  r ', 'the pr ber  e r e he chcken ener ver unfng ', 'all i hve    he f w zng   ', 'oele re  e fr ', 'everhng w freh n elcu ', 'in ur  h w  lrgel ppnng nng experence ', 'i  lke  rell ex pr n ur uh  where u re urgeul flrng wh he he pern  he pr ', 'never been  hr rck cn befre  will never ever step forward in it again ', 'be brekf buffe   ', ' be be  ur p l ', 'we ll never g gn ', 'wll be b ...

# %% [markdown]
# ---
#
# ## Split the dataset

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=1500)
X = cv.fit_transform(corpus).toarray()
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %% [markdown]
# ---
#
# ## Train the model

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ---
#
# ## Predict the results

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# ---
#
# ## Make the Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
confusion_matrix(y_test, y_pred)
# Out:
# array([[43, 55],
#        [12, 90]], dtype=int64)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.665
